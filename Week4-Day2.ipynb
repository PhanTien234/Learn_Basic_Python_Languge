# %%
import pandas as pd

names = ["Jess","Jordan","Sandy","Ted","Barney","Tyler","Rebecca"]
ages= [25,36,21,28,32,27,34]
people = {"names":names,"ages":ages}
df = pd.DataFrame.from_dict(people)
print(df)
# Out:
#      names  ages
# 0     Jess    25
# 1   Jordan    36
# 2    Sandy    21
# 3      Ted    28
# 4   Barney    32
# 5    Tyler    27
# 6  Rebecca    34

# %%
print("=" *50)
print(df["ages"])
print(df["ages"][3])
# Out:
# ...
# 0    25
# 1    36
# 2    21
# 3    28
# 4    32
# 5    27
# 6    34
# Name: ages, dtype: int64
# 28

# %%
print("=" * 50)
print(df.loc[0])
print(df.loc[0]["names"])
print("="*50)
# Out:
# ...
# names    Jess
# ages       25
# Name: 0, dtype: object
# Jess
# ...

# %%
print("="*50)
print(df[2:6])
# Out:
# ...
#     names  ages
# 2   Sandy    21
# 3     Ted    28
# 4  BArney    32
# 5   Tyler    27

# %%
import pandas as pd

names = ["Jess","Jordan","Sandy","Ted","Barney","Tyler","Rebecca"]
ages= [25,36,21,28,32,27,34]
people = {"names":names,"ages":ages}
df = pd.DataFrame.from_dict(people)

df.head(3)
# Out:
#     names  ages
# 0    Jess    25
# 1  Jordan    36
# 2   Sandy    21

# %%
import pandas as pd

names = ["Jess","Jordan","Sandy","Ted","Barney","Tyler","Rebecca"]
ages= [25,36,21,28,32,27,34]
people = {"names":names,"ages":ages}
df = pd.DataFrame.from_dict(people)

df.tail(3)
# Out:
#      names  ages
# 4   Barney    32
# 5    Tyler    27
# 6  Rebecca    34

# %%
import pandas as pd

names = ["Jess","Jordan","Sandy","Ted","Barney","Tyler","Rebecca"]
ages= [25,36,21,28,32,27,34]
people = {"Names Column":names,"Ages Column":ages}
df = pd.DataFrame.from_dict(people)

headers = df.keys
print(headers)
# Out:
# <bound method NDFrame.keys of   Names Column  Ages Column
# 0         Jess           25
# 1       Jordan           36
# 2        Sandy           21
# 3          Ted           28
# 4       Barney           32
# 5        Tyler           27
# 6      Rebecca           34>

# %%
import pandas as pd

names = ["Jess","Jordan","Sandy","Ted","Barney","Tyler","Rebecca"]
ages= [25,36,21,28,32,27,34]
gender = ["Female","Male","Female","Male","Male","Male","Felmale"]
people = {"names":names,"ages":ages,"gender":gender}
df = pd.DataFrame.from_dict(people)

print(df.shape)
# Out:
# (7, 3)

# %%
import pandas as pd

names = ["Jess","Jordan","Sandy","Ted","Barney","Tyler","Rebecca"]
ages= [25,36,21,28,32,27,34]
income=[1000,2000,1200,3000,4000,2800,3400]
gender = ["Female","Male","Female","Male","Male","Male","Felmale"]
people = {"names":names,"ages":ages,"gender":gender,"Income(USD)":income}
df = pd.DataFrame.from_dict(people)

df.describe()#only for numbers
# Out:
#             ages  Income(USD)
# count   7.000000     7.000000
# mean   29.000000  2485.714286
# std     5.291503  1124.616337
# min    21.000000  1000.000000
# 25%    26.000000  1600.000000
# 50%    28.000000  2800.000000
# 75%    33.000000  3200.000000
# max    36.000000  4000.000000

# %%
import pandas as pd

names = ["Jess","Jordan","Sandy","Ted","Barney","Tyler","Rebecca"]
ages= [25,36,21,28,32,27,34]
income=[1000,2000,1200,3000,4000,2800,3400]
gender = ["Female","Male","Female","Male","Male","Male","Felmale"]
people = {"names":names,"ages":ages,"gender":gender,"Income(USD)":income}
df = pd.DataFrame.from_dict(people)

df = df.sort_values("Income(USD)")
print(df)

print("="*50)
df.head(5)
# Out:
#      names  ages   gender  Income(USD)
# 0     Jess    25   Female         1000
# 2    Sandy    21   Female         1200
# 1   Jordan    36     Male         2000
# 5    Tyler    27     Male         2800
# 3      Ted    28     Male         3000
# 6  Rebecca    34  Felmale         3400
# 4   Barney    32     Male         4000
# ...
#     names  ages  gender  Income(USD)
# 0    Jess    25  Female         1000
# 2   Sandy    21  Female         1200
# 1  Jordan    36    Male         2000
# 5   Tyler    27    Male         2800
# 3     Ted    28    Male         3000

# %%
import pandas as pd

names = ["Jess","Jordan","Sandy","Ted","Barney","Tyler","Rebecca"]
ages= [25,36,21,28,32,27,34]
income=[1000,2000,1200,3000,4000,2800,3400]
gender = ["Female","Male","Female","Male","Male","Male","Felmale"]
people = {"names":names,"ages":ages,"gender":gender,"Income(USD)":income}
df = pd.DataFrame.from_dict(people)

can_drink = df["ages"]>21
print(can_drink)
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# Name: ages, dtype: bool

# %%
import pandas as pd

names = ["Jess","Jordan","Sandy","Ted","Barney","Tyler","Rebecca"]
ages= [25,36,21,28,32,27,34]
income=[1000,2000,1200,3000,4000,2800,3400]
gender = ["Female","Male","Female","Male","Male","Male","Felmale"]
people = {"names":names,"ages":ages,"gender":gender,"Income(USD)":income}
df = pd.DataFrame.from_dict(people)

df[ df["Income(USD)"]>2000]
# Out:
#      names  ages   gender  Income(USD)
# 3      Ted    28     Male         3000
# 4   Barney    32     Male         4000
# 5    Tyler    27     Male         2800
# 6  Rebecca    34  Felmale         3400

# %%
import pandas as pd

names = ["Jess","Jordan","Sandy","Ted","Barney","Tyler","Rebecca"]
ages= [25,36,21,28,32,27,34]
income=[1000,2000,1200,3000,4000,2800,3400]
gender = ["Female","Male","Female","Male","Male","Male","Felmale"]
people = {"names":names,"ages":ages,"gender":gender,"Income(USD)":income}
df = pd.DataFrame.from_dict(people)

def incomeLevel(income):
    if income >2000:
        return "High"
    else:
        return"Low"

df["Income_Level"] =df["Income(USD)"].apply(incomeLevel)
df.head(10)
# Out:
#      names  ages   gender  Income(USD) Income_Level
# 0     Jess    25   Female         1000          Low
# 1   Jordan    36     Male         2000          Low
# 2    Sandy    21   Female         1200          Low
# 3      Ted    28     Male         3000         High
# 4   Barney    32     Male         4000         High
# 5    Tyler    27     Male         2800         High
# 6  Rebecca    34  Felmale         3400         High

# %%
import pandas as pd

names = ["Jess","Jordan","Sandy","Ted","Barney","Tyler","Rebecca"]
ages= [25,36,21,28,32,27,34]
income=[1000,2000,1200,3000,4000,2800,3400]
gender = ["Female","Male","Female","Male","Male","Male","Felmale"]
people = {"names":names,"ages":ages,"gender":gender,"Income(USD)":income}
df = pd.DataFrame.from_dict(people)

def incomeLevel(income):
    if income >2000:
        return "High"
    else:
        return"Low"

df["Income_Level"] =df["Income(USD)"].apply(incomeLevel)
df.groupby("Income_Level",as_index=True).count().head() #only for number
# Out:
#               names  ages  gender  Income(USD)
# Income_Level
# High              4     4       4            4
# Low               3     3       3            3

# %%
import pandas as pd

names = ["Jess","Jordan","Sandy","Ted","Barney","Tyler","Rebecca"]
ages= [25,36,21,28,32,27,34]
income=[1000,2000,1200,3000,4000,2800,3400]
gender = ["Female","Male","Female","Male","Male","Male","Felmale"]
people = {"names":names,"ages":ages,"gender":gender,"Income(USD)":income}
df = pd.DataFrame.from_dict(people)

df = df.drop_duplicates(subset="names")
df.head(10)
# Out:
#      names  ages   gender  Income(USD)
# 0     Jess    25   Female         1000
# 1   Jordan    36     Male         2000
# 2    Sandy    21   Female         1200
# 3      Ted    28     Male         3000
# 4   Barney    32     Male         4000
# 5    Tyler    27     Male         2800
# 6  Rebecca    34  Felmale         3400

# %%
import pandas as pd
saleData = pd.read_csv('Sales.csv')
saleData.head(100)
# Out:
#     index  CustomerID  TOTAL_ORDERS   REVENUE  AVERAGE_ORDER_VALUE  \
# 0       0        2354           124  11986.54                96.67
# 1       1        2361            82  11025.96               134.46
# 2       2        2415            43   7259.69               168.83
# 3       3        2427            44   6992.27               158.92
# 4       4        2456            55   6263.44               113.88
# ..    ...         ...           ...       ...                  ...
# 95     95        7063            16   1614.57               100.91
# 96     96        7077            17   1613.09                94.89
# 97     97        7178             4   1596.22               399.06
# 98     98        7195             8   1594.25               199.28
# 99     99        7242            12   1586.89               132.24
#
#     CARRIAGE_REVENUE  AVERAGESHIPPING FIRST_ORDER_DATE LATEST_ORDER_DATE  \
# 0             529.59             4.27       2016-12-30        2021-10-24
# ...

# %%
saleData.describe()
# Out:
#              index     CustomerID  TOTAL_ORDERS       REVENUE  \
# count  5000.000000    5000.000000    5000.00000   5000.000000
# mean   2499.500000   43041.227800      12.87040   1681.523840
# std    1443.520003   49949.848017      12.67988   1998.618678
# min       0.000000    2333.000000       1.00000     38.500000
# 25%    1249.750000    4019.500000       3.00000    315.097500
# 50%    2499.500000   16097.000000       8.00000    966.725000
# 75%    3749.250000   74223.500000      20.00000   2493.072500
# max    4999.000000  279492.000000     156.00000  34847.400000
#
#        AVERAGE_ORDER_VALUE  CARRIAGE_REVENUE  AVERAGESHIPPING  \
# count          5000.000000       5000.000000      5000.000000
# mean            136.537378         46.036376         3.592574
# std              91.651569         47.879226         2.021360
# min              10.680000          0.000000         0.000000
# 25%              83.025000          9.980000         2.500000
# ...

# %%
saleData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 41 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      5000 non-null   int64
#  1   CustomerID                 5000 non-null   int64
#  2   TOTAL_ORDERS               5000 non-null   int64
#  3   REVENUE                    5000 non-null   float64
#  4   AVERAGE_ORDER_VALUE        5000 non-null   float64
#  5   CARRIAGE_REVENUE           5000 non-null   float64
#  6   AVERAGESHIPPING            5000 non-null   float64
#  7   FIRST_ORDER_DATE           5000 non-null   object
#  8   LATEST_ORDER_DATE          5000 non-null   object
#  9   AVGDAYSBETWEENORDERS       5000 non-null   float64
#  10  DAYSSINCELASTORDER         5000 non-null   int64
#  11  MONDAY_ORDERS              5000 non-null   int64
#  12  TUESDAY_ORDERS             5000 non-null   int64
# ...
